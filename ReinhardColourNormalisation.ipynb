# %%
import numpy as np
import PIL 
from histomicstk.preprocessing.color_normalization import reinhard
from histomicstk.preprocessing.color_normalization import reinhard_stats
import glob
import matplotlib.pyplot as plt

# %%
all_imgs = glob.glob('C:\\Users\\Test\\Documents\\sxb1208satvika\\ThreeClassSegmentation\\InputImages\\im\\B09-17\\*.jpg')
image_list = []
slide_path = 'C:\\Users\\Test\\Documents\\sxb1208satvika\\ThreeClassSegmentation\\InputImages\\im\\B09-17\\IM.jpg'
image = PIL.Image.open(slide_path).convert('RGB')
plt.imshow(image,cmap='gray'); plt.show();
stats = reinhard_stats(slide_path, 1)
print(stats)

for img_path in all_imgs:
#     image_list.append(np.array(PIL.Image.open(img_path).convert('RGB')))
    img= np.array(PIL.Image.open(img_path).convert('RGB'))
    plt.imshow(img,cmap='gray'); plt.show();
    img = reinhard(img, target_mu=stats[0], target_sigma=stats[1])
    plt.imshow(img,cmap='gray'); plt.show();
# Out:
# ReinhardStats(Mu=array([ 8.51405366, -0.34003247, -0.06113033]), Sigma=array([0.9133801 , 0.45897853, 0.09125473]))

# %%
image_array = np.array(image_list)
print(image_array.shape)

# %%
print(stats)

# %%
print(stats)

# %%
slide_path = 'C:\\Users\\Test\\Documents\\sxb1208satvika\\ThreeClassSegmentation\\InputImages\\im\\B09-17\\A2.jpg'
stats = reinhard_stats(slide_path, 1, magnification=20,tissue_seg_mag=1.25)
